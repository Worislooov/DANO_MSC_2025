# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("data.xlsx")
df.head()
# Out:
#   calendar_dt                       id_employee  useful_calls_fact  \
# 0  2024-10-22  b85a5824cc3411e3429bd49054ffcc17               1225
# 1  2024-10-22  611677896b031565a86d510977572ddf                  0
# 2  2024-09-20  3506d80afbdc2f1ddcee2ce65e7d82ee                  0
# 3  2024-12-25  a497350c6c8542c1e79ae2b83e6c782d              11483
# 4  2024-09-20  34f30cdf1ab7f0195a74ef15963c29a5               1426
#
#    useful_chats_fact  avail_calls_fact  avail_chats_fact  \
# 0                  0              2542                 0
# 1                  0                 0                 0
# 2              21235                 0               372
# 3              27466                 3               130
# 4              30649               184              2119
#
#    avail_chat_call_fact  break_fact  education_fact  additional_fact  ...  \
# 0                     0           0           27598                0  ...
# 1                     0           0               0                0  ...
# 2                     0        4208               0                1  ...
# 3                     0        4810               0                1  ...
# 4                     0        6028               0             2827  ...
#
#    planning_group_nm  residential_district_nm  residential_city_nm  \
# 0                NaN                      NaN              г Пермь
# 1                NaN                      NaN            г Энгельс
# 2                NaN         Нижнекамский р-н         г Нижнекамск
# 3                NaN     Катав-Ивановский р-н     г Катав-Ивановск
# 4                NaN                      NaN         г Ставрополь
#
#    residential_state_nm  residential_settlement_nm  grafik cnt_call  \
# 0         Пермский край                        NaN     5/2      3.0
# 1       Саратовская обл                        NaN     2/2      NaN
# 2        Респ Татарстан                        NaN     5/2      NaN
# 3       Челябинская обл                        NaN     5/2     35.0
# 4   Ставропольский край                        NaN     2/2      4.0
#
#   dlg_time_call cnt_chat dlg_time_chat
# 0         497.0      NaN           NaN
# 1           NaN      NaN           NaN
# 2           NaN    136.0       31416.0
# 3        8223.0     78.0       39998.0
# 4         540.0    258.0       51885.0
#
# [5 rows x 35 columns]

# %%
df.to_csv('data.csv', index=False)
