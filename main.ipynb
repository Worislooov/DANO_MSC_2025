# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from cool_functions import *


print("halo dano")
df = pd.read_excel('data\example.xlsx') # пример бд
do_all(df) # пример анализа (можно удалить)
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\e'
# <>:10: SyntaxWarning: invalid escape sequence '\e'
# C:\Users\DukeOfTimes\AppData\Local\Temp\ipykernel_11660\2613584831.py:10: SyntaxWarning: invalid escape sequence '\e'
#   df = pd.read_excel('data\example.xlsx')
# halo dano
# ══════════════════════════════════════════════════
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97307 entries, 0 to 97306
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   party_rk                   97307 non-null  int64
#  1   region                     97307 non-null  object
#  2   offenceshortstatement      97307 non-null  object
#  3   offencedate                97307 non-null  datetime64[ns]
#  4   offencetime                97307 non-null  object
#  5   engine_type                97307 non-null  object
#  6   engine_power               97302 non-null  object
# ...

# %%
width=0.4
x_list = list(range(0,5))
y1_list = [22, 17,81,41,25]
y2_list = [22, 14,11,61,65]
x_indexes = np.arange(len(x_list))

plt.title("Salary")
plt.xlabel("days")
plt.ylabel('salary,$')
#plt.plot(x_list,y1_list, label="Mark")
#plt.plot(x_list,y2_list, label="Steve")
plt.bar(x_indexes - (width/2),y1_list, label="Mark", width=width)
plt.bar(x_indexes + (width/2),y2_list, label="Steve", width=width)
plt.legend()
plt.show()
